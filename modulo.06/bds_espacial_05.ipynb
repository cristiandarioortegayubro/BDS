# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/BDS/blob/main/modulo.06/bds_espacial_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20BDS%20Horizontal%208.png?raw=true">
# </p>

# %% [markdown]
# <p align="center">
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/nominatim.svg?raw=true" width="200">
# </p>

# %% [markdown]
#  # **<font color="DeepPink">Transformar direcciones postales a coordenadas</font>**

# %% [markdown]
#  ## **<font color="DeepPink">Geolocalización</font>**

# %% [markdown]
# <p align="justify">
# La geolocalización es una tecnología fundamental en la era digital que nos permite determinar la ubicación geográfica precisa de objetos, personas o lugares en la Tierra. Desde aplicaciones de navegación hasta redes sociales y análisis de datos, la geolocalización desempeña un papel fundamental en una amplia variedad de campos. En este colab, exploraremos cómo utilizar las herramientas <code>Geopy</code> y <code>Nominatim</code> para llevar a cabo tareas de geolocalización de manera efectiva.

# %% [markdown]
#  ## **<font color="DeepPink">Geopy: Geolocalización Simplificada</font>**

# %% [markdown]
# <p align="justify">
# <code>Geopy</code> es una biblioteca de Python que ofrece una interfaz sencilla para acceder a varios servicios de geolocalización. Con <code>Geopy</code>, podemos realizar una variedad de tareas relacionadas con la geolocalización, como obtener coordenadas geográficas a partir de direcciones y viceversa, calcular distancias entre ubicaciones y buscar lugares cercanos a una posición dada.

# %% [markdown]
#  ## **<font color="DeepPink">Nominatim: Motor de Búsqueda Geográfica</font>**

# %% [markdown]
# <p align="justify">
# <code>Nominatim</code> es un servicio de búsqueda geográfica desarrollado por OpenStreetMap, la cual es una iniciativa de mapeo colaborativo a nivel mundial.
# <br><br>
# <code>Nominatim</code> (<a href='https://nominatim.org/'>https://nominatim.org/</a>) permite realizar búsquedas geográficas utilizando direcciones o descripciones de lugares, y devuelve información detallada sobre la ubicación, como las coordenadas geográficas, el tipo de lugar y otros datos relevantes.

# %% [markdown]
#  ## **<font color="DeepPink">Instalación y carga de bibliotecas</font>**

# %%
from geopy.geocoders import Nominatim
import pandas as pd
import os
import numpy as np
import geopandas as gpd
import plotly.express as px

# %% [markdown]
#  ## **<font color="DeepPink">Carga del conjunto de datos</font>**
#
#  Para mostrar como conseguir las coordenadas geográficas vamos trabajar con un conjunto de datos de alumnos de la Facultad de Ciencias Económicas.

# %%
url = "https://raw.githubusercontent.com/gustavomachin/RendimientoAcademico/main/AlumnosFCEDatosPersonales.csv"

# %%
data=pd.read_csv(url, sep=";", encoding='latin1')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3775 entries, 0 to 3774
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             3775 non-null   int64
#  1   estado_civil                   3771 non-null   float64
#  2   unido_hecho                    3773 non-null   object
#  3   situacion_padre                3745 non-null   object
#  4   situacion_madre                3747 non-null   object
#  5   cantidad_hijos                 3735 non-null   float64
#  6   cantidad_familia               3688 non-null   float64
#  7   turno_preferido                3565 non-null   float64
#  8   cobertura_salud                3615 non-null   float64
#  9   tipo_vivienda                  3003 non-null   float64
#  10  vive_con                       3649 non-null   float64
#  11  periodo_lectivo_calle          3768 non-null   object
#  12  periodo_lectivo_numero         3763 non-null   object
#  13  periodo_lectivo_piso           709 non-null    object
#  14  periodo_lectivo_departamento   908 non-null    object
#  15  periodo_lectivo_unidad         404 non-null    object
#  16  periodo_lectivo_localidad      3762 non-null   float64
#  17  periodo_lectivo_barrio         1538 non-null   object
#  18  periodo_lectivo_codigo_postal  3758 non-null   float64
#  19  procedencia_calle              3758 non-null   object
#  20  procedencia_numero             3755 non-null   object
#  21  procedencia_piso               552 non-null    object
#  22  procedencia_departamento       699 non-null    object
#  23  procedencia_unidad             358 non-null    object
#  24  procedencia_localidad          3753 non-null   float64
#  25  procedencia_barrio             1512 non-null   object
#  26  procedencia_codigo_postal      3748 non-null   float64
#  27  es_celiaco                     1985 non-null   object
# dtypes: float64(11), int64(1), object(16)
# memory usage: 825.9+ KB

# %% [markdown]
# <p align='justify'>
# Preparamos los datos y eliminamos columnas que no vamos a utilizar, nos enfocaremos solo en obtener las coordenadas a partir de las direcciones.

# %%
data = data.iloc[:,11:19]
data
# Out:
#         periodo_lectivo_calle periodo_lectivo_numero periodo_lectivo_piso  \
# 0                    Arenales                   1180                  NaN
# 1             Lisandro Moyano                   1077                    8
# 2              Barrio Dalvian                   1345                  NaN
# 3                 El Portillo                    473                  NaN
# 4              Alfredo Bufano                    376                  NaN
# ...                       ...                    ...                  ...
# 3770  Prolongación Corrientes                     52                  NaN
# 3771                      NaN                     54                    1
# 3772                      NaN                    S/n                  NaN
# 3773             Doctor Lemos                    890                  NaN
# 3774             Las Amapolas                   2913                  NaN
#
#      periodo_lectivo_departamento periodo_lectivo_unidad  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
# ...                           ...                    ...
# 3770                          NaN                    NaN
# 3771                            5                      1
# 3772                          NaN                    NaN
# 3773                          NaN                    NaN
# 3774                          NaN                    NaN
#
#       periodo_lectivo_localidad periodo_lectivo_barrio  \
# 0                       13217.0                  Fuchs
# 1                       13208.0         Ciudad Capital
# 2                       50352.0                    NaN
# 3                       13488.0                 Jardin
# 4                       13208.0                Dalvian
# ...                         ...                    ...
# 3770                    13208.0                    NaN
# 3771                    13616.0                    NaN
# 3772                    13217.0                    NaN
# 3773                    13272.0                 Covipa
# 3774                    13274.0        17 De Noviembre
#
#       periodo_lectivo_codigo_postal
# 0                            5501.0
# 1                            5500.0
# 2                            5519.0
# 3                            5570.0
# 4                            5500.0
# ...                             ...
# 3770                         5500.0
# 3771                         5600.0
# 3772                         5501.0
# 3773                         5519.0
# 3774                         5519.0
#
# [3775 rows x 8 columns]

# %%
data.drop(columns=["periodo_lectivo_piso", "periodo_lectivo_departamento", "periodo_lectivo_unidad", "periodo_lectivo_barrio", "periodo_lectivo_localidad"], inplace=True)

# %%
data.head()
# Out:
#   periodo_lectivo_calle periodo_lectivo_numero  periodo_lectivo_codigo_postal
# 0              Arenales                   1180                         5501.0
# 1       Lisandro Moyano                   1077                         5500.0
# 2        Barrio Dalvian                   1345                         5519.0
# 3           El Portillo                    473                         5570.0
# 4        Alfredo Bufano                    376                         5500.0

# %%
data = data.dropna()

# %%
data
# Out:
#         periodo_lectivo_calle periodo_lectivo_numero  \
# 0                    Arenales                   1180
# 1             Lisandro Moyano                   1077
# 2              Barrio Dalvian                   1345
# 3                 El Portillo                    473
# 4              Alfredo Bufano                    376
# ...                       ...                    ...
# 3768           San Juan Bosco                    147
# 3769           San Juan Bosco                    589
# 3770  Prolongación Corrientes                     52
# 3773             Doctor Lemos                    890
# 3774             Las Amapolas                   2913
#
#       periodo_lectivo_codigo_postal
# 0                            5501.0
# 1                            5500.0
# 2                            5519.0
# 3                            5570.0
# 4                            5500.0
# ...                             ...
# 3768                         5500.0
# 3769                         5525.0
# 3770                         5500.0
# 3773                         5519.0
# 3774                         5519.0
#
# [3746 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3746 entries, 0 to 3774
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   periodo_lectivo_calle          3746 non-null   object
#  1   periodo_lectivo_numero         3746 non-null   object
#  2   periodo_lectivo_codigo_postal  3746 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 117.1+ KB

# %%
data = data.rename(columns={"periodo_lectivo_calle":"calle",
                            "periodo_lectivo_numero":"numero",
                            "periodo_lectivo_codigo_postal":"cp"})

# %%
data.head()
# Out:
#              calle numero      cp
# 0         Arenales   1180  5501.0
# 1  Lisandro Moyano   1077  5500.0
# 2   Barrio Dalvian   1345  5519.0
# 3      El Portillo    473  5570.0
# 4   Alfredo Bufano    376  5500.0

# %% [markdown]
# Eliminamos todas aquellas direcciones que nos vengan sin número para no tener problemas en la búsqueda de la coordenada.

# %%
data.drop(data[data.numero == "S/n"].index, axis=0, inplace=True)

# %% [markdown]
# <p align='justify'>
# Los códigos postales son importantes para la búsqueda de la coordenada ya que ayuda a ubicar la provincia, el país, etc. También se puede pasar la ciudad, provincia y país. El formato que debe llevar este tiene que ser en formato entero, para que <code>Nominatim</code> lo pueda interpretar.

# %%
data.cp = data.cp.astype("int")

# %%
data.head()
# Out:
#              calle numero    cp
# 0         Arenales   1180  5501
# 1  Lisandro Moyano   1077  5500
# 2   Barrio Dalvian   1345  5519
# 3      El Portillo    473  5570
# 4   Alfredo Bufano    376  5500

# %% [markdown]
#  ## **<font color="DeepPink">Localización con nominatim</font>**

# %% [markdown]
# <p align='justify'>
# Cada servicio de geolocalización como Google Maps, Bing Maps, Yahoo, MapQuest o Nominatim tiene su propia clase en <code>geopy.geocoders</code> para utilizar el servicio API.
# <br><br>
# Creamos un objeto llamado geolocalizador a partir de la clase <code>Nominatim()</code>.

# %%
geolocalizador = Nominatim(user_agent = "http")

# %%
punto[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-21ea8caa27a5> in <cell line: 1>()
# ----> 1 punto[0]
#
# NameError: name 'punto' is not defined

# %% [markdown]
# Ya con este geolocalizador podemos ubicar la dirección que deseemos. Por ejemplo, vamos a localizar la Plaza Independencia de Mendoza.

# %%
geolocalizador.geocode(["Patricias Mendocinas",1157, 5500,"Mendoza"])
# Out:
# Location(Patricias Mendocinas, Ciudad de Mendoza, Sección 2ª Barrio Cívico, Departamento Capital, Mendoza, M5500EAV, Argentina, (-32.8878174, -68.8426548, 0.0))

# %%
geolocalizador.geocode(["Patricias Mendocinas",1157, "Departamento Capital","Mendoza", "Argentina"])
# Out:
# Location(Patricias Mendocinas, Ciudad de Mendoza, Sección 2ª Barrio Cívico, Departamento Capital, Mendoza, M5500EAV, Argentina, (-32.8878174, -68.8426548, 0.0))

# %% [markdown]
# <p align='justify'>
# Ahora vamos a generar la localización de cada uno de los datos de nuestro dataframe.
# <br><br>
# Creamos un nueva lista donde se guardarán las localizaciones y una lista de errores porque puede pasar que no se encuentre la dirección. Luego iteramos por cada una de las filas del dataframe para pasar las direcciones.

# %%
localizaciones = []
errores = []
# Itreamos por cada una de las filas
for i in range(len(data.iloc[:50])):
    # Armamos la lista con los valores que representan la dirección
    val = data.iloc[i].values
    direccion = geolocalizador.geocode(val, timeout=15)

    # Intentamos trar la dirección en  caso que falle pasamos valores nulos y agregamos la fila a errores
    try:
      localizaciones.append((direccion.latitude, direccion.longitude))
    except AttributeError:
      localizaciones.append((None,None))
      errores.append(val)

# %%
localizaciones
# Out:
# [(-32.9657601, -68.827711),
#  (-32.8622709, -68.8217583),
#  (-32.8675765, -68.888668),
#  (None, None),
#  (-32.9610054, -68.7872968),
#  (-32.9390449, -68.80801),
#  (-31.4987885, -68.5390528),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (-32.924487, -68.8210383),
#  (None, None),
#  (-32.9663876, -68.7885983),
#  (-32.8473592, -68.8149837),
#  (-32.920791618367346, -68.85524507346939),
#  (-32.9245226, -68.8158237),
#  (-32.9842082, -68.7936393),
#  (None, None),
#  (-32.8374758, -68.7710202),
#  (-32.9511332, -68.8599457),
#  (None, None),
#  (None, None),
#  (-32.892613, -68.8603647),
#  (-33.0349314, -68.8909197),
#  (-34.623512522448976, -68.34162770612245),
#  (None, None),
#  (-32.9086247, -68.8293469),
#  (-32.9631961, -68.8641836),
#  (None, None),
#  (-32.90771064545454, -68.84995176060606),
#  (None, None),
#  (-32.9881374, -68.82978655691126),
#  (-32.9099276, -68.8274926),
#  (-32.894701433557046, -68.84992749060403),
#  (None, None),
#  (-32.927975841666665, -68.83470407916667),
#  (None, None),
#  (-32.8820462, -68.8155955),
#  (-32.8808928, -68.8553652),
#  (None, None),
#  (None, None),
#  (35.1138572, 33.2863083),
#  (None, None),
#  (-32.9582739, -68.7093498),
#  (-32.93578472448979, -68.85614317346939),
#  (None, None),
#  (-32.7983971, -68.8250268)]

# %%
errores
# Out:
# [array(['El Portillo', '473', 5570], dtype=object),
#  array(['Barrio Cooperativa Jocoli M D C 13', '290', 5600], dtype=object),
#  array(['Cayetano Silva', '4616', 5533], dtype=object),
#  array(['Dr. Schestakow', '5', 5529], dtype=object),
#  array(['Monseñor Manuel Álvarez', '142', 5500], dtype=object),
#  array(['B° S.p.u.n.c Manz "b"', '3141', 5500], dtype=object),
#  array(['Helen Keller', '4041', 5521], dtype=object),
#  array(['Río Tunuyán', '28B', 5570], dtype=object),
#  array(['Los Paraisos Bº 22 De Octubre Manzana E', 'Mh C8', 5515],
#        dtype=object),
#  array(['Arturo Gonzalez', '3191', 5500], dtype=object),
#  array(['San Lorenzo', 'Mdc2', 5533], dtype=object),
#  array(['Club De Campo Mendoza, Manzana J, Casa 7', '6507', 5521],
#        dtype=object),
#  array(['Callejon Fernandez', '360', 5515], dtype=object),
#  array(['Los Paraisos', '55', 5600], dtype=object),
#  array(['Bruno Moron', '29', 5533], dtype=object),
#  array(['Cerro Angostura', '5383', 5517], dtype=object),
#  array(['Granaderos', '1803', 5541], dtype=object),
#  array(['Trinidad Tobago', '2485', 5500], dtype=object),
#  array(['Abdon Zgaib', '325', 5607], dtype=object),
#  array(['Isadora Duncan Mza G- Casa 29. B° Costa De Araujo', '2858', 5521],
#        dtype=object)]

# %%
data2 = data.iloc[:50]

# %%
data2['latitud'] = np.array(localizaciones)[:,0]
data2['longitud'] = np.array(localizaciones)[:,1]
# Out:
# <ipython-input-40-d011080daf59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['latitud'] = np.array(localizaciones)[:,0]
# <ipython-input-40-d011080daf59>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['longitud'] = np.array(localizaciones)[:,1]

# %%
data_geo = gpd.GeoDataFrame(data2, geometry = gpd.points_from_xy(data2.latitud, data2.longitud))

# %%
data_geo.head()
# Out:
#              calle numero    cp    latitud   longitud  \
# 0         Arenales   1180  5501  -32.96576 -68.827711
# 1  Lisandro Moyano   1077  5500 -32.862271 -68.821758
# 2   Barrio Dalvian   1345  5519 -32.867576 -68.888668
# 3      El Portillo    473  5570       None       None
# 4   Alfredo Bufano    376  5500 -32.961005 -68.787297
#
#                       geometry
# 0  POINT (-32.96576 -68.82771)
# 1  POINT (-32.86227 -68.82176)
# 2  POINT (-32.86758 -68.88867)
# 3                  POINT EMPTY
# 4  POINT (-32.96101 -68.78730)

# %%
data_geo2 = data_geo.dropna()

# %%
data_geo2.head()
# Out:
#              calle numero    cp    latitud   longitud  \
# 0         Arenales   1180  5501  -32.96576 -68.827711
# 1  Lisandro Moyano   1077  5500 -32.862271 -68.821758
# 2   Barrio Dalvian   1345  5519 -32.867576 -68.888668
# 4   Alfredo Bufano    376  5500 -32.961005 -68.787297
# 7          Riveros   2350  5500 -32.939045  -68.80801
#
#                       geometry
# 0  POINT (-32.96576 -68.82771)
# 1  POINT (-32.86227 -68.82176)
# 2  POINT (-32.86758 -68.88867)
# 4  POINT (-32.96101 -68.78730)
# 7  POINT (-32.93904 -68.80801)

# %% [markdown]
# Mapeamos los puntos con <code>plotly</code>, ya que tiene sus propias visualizaciones que mapean.

# %%
fig = px.scatter_mapbox(data_geo2,
                        lat="latitud",
                        lon="longitud",
                        hover_data=["calle", "numero", "cp"],
                        center={"lat":-32.882699833649745, "lon":-68.87827123082963}, #UNCuyo
                        zoom=9
                        )
fig.update_layout(mapbox_style="open-street-map")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fe6d4a13-f1be-47af-946a-f9d9796964f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe6d4a13-f1be-47af-946a-f9d9796964f6")) {                    Plotly.newPlot(                        "fe6d4a13-f1be-47af-946a-f9d9796964f6",                        [{"customdata":[["Arenales","1180",5501],["Lisandro Moyano","1077",5500],["Barrio Dalvian","1345",5519],["Alfredo Bufano","376",5500],["Riveros","2350",5500],["Azcuenaga","1",5570],["Tandil","394",5511],["Juan B Justo","4165",5521],["Democracia M F","100",5577],["Parana","837",5500],["San Francisco Del Monte","335",5519],["Vergara","432",5519],["Gutemberg","0",5539],["laguna del diamante","2200",5503],["Huarpes","437",5501],["Espa\u00f1a","2771",5509],["Almafuerte","564",5600],["Suipacha","564",5539],["Gutenberg","688",5500],["Tucuman","464",5501],["Boedo","470",5500],["Tucuman","2120",5519],["Peru","550",5500],["Juan Xxiii Godoy Cruz","178",5501],["Vicente L\u00f3pez Y Planes","1460",5501],["S\u00e1enz Pe\u00f1a","2675",5500],["Georgias Del Sur","2798",5521],["Ruta Provincial","50",5501],["italia","1023",5519],["San Mart\u00edn","52",5539]],"hovertemplate":"latitud=%{lat}<br>longitud=%{lon}<br>calle=%{customdata[0]}<br>numero=%{customdata[1]}<br>cp=%{customdata[2]}<extra></extra>","lat":[-32.9657601,-32.8622709,-32.8675765,-32.9610054,-32.9390449,-31.4987885,-32.924487,-32.9663876,-32.8473592,-32.920791618367346,-32.9245226,-32.9842082,-32.8374758,-32.9511332,-32.892613,-33.0349314,-34.623512522448976,-32.9086247,-32.9631961,-32.90771064545454,-32.9881374,-32.9099276,-32.894701433557046,-32.927975841666665,-32.8820462,-32.8808928,35.1138572,-32.9582739,-32.93578472448979,-32.7983971],"legendgroup":"","lon":[-68.827711,-68.8217583,-68.888668,-68.7872968,-68.80801,-68.5390528,-68.8210383,-68.7885983,-68.8149837,-68.85524507346939,-68.8158237,-68.7936393,-68.7710202,-68.8599457,-68.8603647,-68.8909197,-68.34162770612245,-68.8293469,-68.8641836,-68.84995176060606,-68.82978655691126,-68.8274926,-68.84992749060403,-68.83470407916667,-68.8155955,-68.8553652,33.2863083,-68.7093498,-68.85614317346939,-68.8250268],"marker":{"color":"#636efa"},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555 ...

# %% [markdown]
#  # **<font color="DeepPink">Conclusiones</font>**

# %% [markdown]
# <p align="justify">
# 👀 En este colab nosotros:<br><br>
# ✅ Aprendimos que funciones tiene <code>geopy</code>.<br>
# ✅ Utilizamos <code>nominatim</code> y <code>geopy</code> para obtener coordenadas.<br>
# ✅ Mapeamos los puntos encontrados con <code>plotly<code>.<br>
#
# <p align="justify">

# %% [markdown]
# <br>
# <br>
# <p align="center"><b>
# 💗
# <font color="DeepPink">
# Hemos llegado al final de nuestro colab, a seguir codeando...
# </font>
# </p>
# <br>
# <p align="center">
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20BDS%20Horizontal%208.png?raw=true">
# </p>
#
# ---
