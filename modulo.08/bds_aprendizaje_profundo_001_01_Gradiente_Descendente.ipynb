# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/BDS/blob/main/modulo.08/bds_aprendizaje_profundo_001_01_Gradiente_Descendente.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20BDS%20Horizontal%208.png?raw=true">
# </p>

# %% [markdown]
#  # **<font color="DeepPink">Gradiente Descendente</font>**

# %% [markdown]
# Ejemplo extraído de: https://induraj2020.medium.com/implementing-gradient-descent-in-python-d1c6aeb9a448

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
# Define the function to be minimized (a simple quadratic function)
def f(x, y):
    return x**2 + y**2

# %%
# Define the partial derivatives of the function with respect to x and y
def df_dx(x, y):
    return 2 * x

def df_dy(x, y):
    return 2 * y

# %% [markdown]
# Gradient Descent:
#
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/gradiente%20descendente.jpg?raw=true">

# %%
# Define the gradient descent algorithm

def gradient_descent(start_x, start_y, learning_rate, num_iterations):
    # Initialize the parameters
    x = start_x
    y = start_y
    history = []

    # Perform the gradient descent iterations
    for i in range(num_iterations):
        # Calculate the gradients
        grad_x = df_dx(x, y)
        grad_y = df_dy(x, y)

        # Update the parameters
        x = x - learning_rate * grad_x
        y = y - learning_rate * grad_y

        # Save the history of the parameters
        history.append((x, y, f(x, y)))

    return x, y, f(x, y), history

# %%
# Define the meshgrid for plotting the function
x_range = np.arange(-10, 10, 0.1)
y_range = np.arange(-10, 10, 0.1)
X, Y = np.meshgrid(x_range, y_range)
Z = f(X, Y)

# %%
# Perform gradient descent and plot the results
start_x, start_y = 8, 9
learning_rate = 0.1
num_iterations = 30
x_opt, y_opt, f_opt, history = gradient_descent(start_x, start_y, learning_rate, num_iterations)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='coolwarm')
ax.scatter(*zip(*history), c='r', marker='o')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
plt.show()

# %%
f_opt
# Out:
# 0.00022221185342555393

# %%
x_opt
# Out:
# 0.009903520314283045

# %%
y_opt
# Out:
# 0.011141460353568422

# %%
history2 = pd.DataFrame(history)
history2.columns = ["X", "y", "f(x)"]
history2
# Out:
#            X         y       f(x)
# 0   6.400000  7.200000  92.800000
# 1   5.120000  5.760000  59.392000
# 2   4.096000  4.608000  38.010880
# 3   3.276800  3.686400  24.326963
# 4   2.621440  2.949120  15.569256
# 5   2.097152  2.359296   9.964324
# 6   1.677722  1.887437   6.377167
# 7   1.342177  1.509949   4.081387
# 8   1.073742  1.207960   2.612088
# 9   0.858993  0.966368   1.671736
# 10  0.687195  0.773094   1.069911
# 11  0.549756  0.618475   0.684743
# 12  0.439805  0.494780   0.438236
# 13  0.351844  0.395824   0.280471
# 14  0.281475  0.316659   0.179501
# 15  0.225180  0.253327   0.114881
# 16  0.180144  0.202662   0.073524
# 17  0.144115  0.162130   0.047055
# 18  0.115292  0.129704   0.030115
# 19  0.092234  0.103763   0.019274
# 20  0.073787  0.083010   0.012335
# 21  0.059030  0.066408   0.007895
# 22  0.047224  0.053127   0.005053
# 23  0.037779  0.042501   0.003234
# 24  0.030223  0.034001   0.002070
# 25  0.024179  0.027201   0.001324
# 26  0.019343  0.021761   0.000848
# 27  0.015474  0.017409   0.000543
# 28  0.012379  0.013927   0.000347
# 29  0.009904  0.011141   0.000222

# %% [markdown]
# <br>
# <br>
# <p align="center"><b>
# 💗
# <font color="DeepPink">
# Hemos llegado al final de nuestro colab...
# </font>
# </p>
# <br>
# <p align="center">
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20BDS%20Horizontal%208.png?raw=true">
# </p>
#
# ---
