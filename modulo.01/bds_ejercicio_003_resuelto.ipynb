# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/BDS/blob/main/modulo.01/bds_ejercicio_003_resuelto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20BDS%20Horizontal%208.png?raw=true">
# </p>

# %% [markdown]
# <p align="center">
# <img src="https://www.python.org/static/community_logos/python-powered-h-70x91.png">
# </p>

# %% [markdown]
# # ☯ <font color="DeepPink">**Actividad 003**</font>

# %% [markdown]
# ## 🔹 **<font color="DeepPink">Actualización de la biblioteca requerida</font>**

# %%
# !pip install plotly --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.8/dist-packages (5.13.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly) (8.1.0)

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Habilitando bibliotecas requeridas**</font>

# %% [markdown]
# ### **<font color="DeepPink">Para análisis de datos</font>**

# %%
import pandas as pd
import yfinance as yf # La usamos para traer datos remotos desde yahoo finanzas

# %% [markdown]
# ### **<font color="DeepPink">Biblioteca gráfica</font>**

# %%
import plotly.express as px

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Cotización acciones de Microsoft, Apple y Google**</font>

# %% [markdown]
# ### <font color="DeepPink">**Cotización de Microsoft**</font>

# %% [markdown]
# Ejecutar el siguiente script...

# %%
MSFT = yf.download("MSFT", start="2022-01-01", end="2022-03-31").round(2)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### <font color="DeepPink">**Cotización de Apple**</font>

# %% [markdown]
# Ejecutar el siguiente script...

# %%
AAPL = yf.download("AAPL", start="2022-01-01", end="2022-03-31").round(2)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### <font color="DeepPink">**Cotización de Google**</font>

# %% [markdown]
# Ejecutar el siguiente script...

# %%
GOOG = yf.download("GOOG", start="2022-01-01", end="2022-03-31").round(2)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Actividades con el DataFrame**</font>

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Visualizar los tres dataframes**
# </font>
# </p>

# %%
MSFT
# Out:
#                              Open    High     Low   Close  Adj Close    Volume
# Date
# 2022-01-03 00:00:00-05:00  335.35  338.00  329.78  334.75     331.64  28865100
# 2022-01-04 00:00:00-05:00  334.83  335.20  326.12  329.01     325.96  32674300
# 2022-01-05 00:00:00-05:00  325.86  326.07  315.98  316.38     313.44  40054300
# 2022-01-06 00:00:00-05:00  313.15  318.70  311.49  313.88     310.97  39646100
# 2022-01-07 00:00:00-05:00  314.15  316.50  310.09  314.04     311.12  32720000
# ...                           ...     ...     ...     ...        ...       ...
# 2022-03-24 00:00:00-04:00  299.14  304.20  298.32  304.10     301.90  24484500
# 2022-03-25 00:00:00-04:00  305.23  305.50  299.29  303.68     301.48  22566500
# 2022-03-28 00:00:00-04:00  304.33  310.80  304.33  310.70     308.45  29578200
# 2022-03-29 00:00:00-04:00  313.91  315.82  309.05  315.41     313.13  30393400
# 2022-03-30 00:00:00-04:00  313.76  315.95  311.58  313.86     311.59  28163600
#
# [61 rows x 6 columns]

# %%
AAPL
# Out:
#                              Open    High     Low   Close  Adj Close  \
# Date
# 2022-01-03 00:00:00-05:00  177.83  182.88  177.71  182.01     180.96
# 2022-01-04 00:00:00-05:00  182.63  182.94  179.12  179.70     178.66
# 2022-01-05 00:00:00-05:00  179.61  180.17  174.64  174.92     173.91
# 2022-01-06 00:00:00-05:00  172.70  175.30  171.64  172.00     171.01
# 2022-01-07 00:00:00-05:00  172.89  174.14  171.03  172.17     171.18
# ...                           ...     ...     ...     ...        ...
# 2022-03-24 00:00:00-04:00  171.06  174.14  170.21  174.07     173.29
# 2022-03-25 00:00:00-04:00  173.88  175.28  172.75  174.72     173.93
# 2022-03-28 00:00:00-04:00  172.17  175.73  172.00  175.60     174.81
# 2022-03-29 00:00:00-04:00  176.69  179.01  176.34  178.96     178.15
# 2022-03-30 00:00:00-04:00  178.55  179.61  176.70  177.77     176.97
#
#                               Volume
# Date
# 2022-01-03 00:00:00-05:00  104487900
# 2022-01-04 00:00:00-05:00   99310400
# 2022-01-05 00:00:00-05:00   94537600
# 2022-01-06 00:00:00-05:00   96904000
# 2022-01-07 00:00:00-05:00   86709100
# ...                              ...
# 2022-03-24 00:00:00-04:00   90131400
# 2022-03-25 00:00:00-04:00   80546200
# 2022-03-28 00:00:00-04:00   90371900
# 2022-03-29 00:00:00-04:00  100589400
# 2022-03-30 00:00:00-04:00   92633200
#
# [61 rows x 6 columns]

# %%
GOOG
# Out:
#                              Open    High     Low   Close  Adj Close    Volume
# Date
# 2022-01-03 00:00:00-05:00  144.48  145.55  143.50  145.07     145.07  25214000
# 2022-01-04 00:00:00-05:00  145.55  146.61  143.82  144.42     144.42  22928000
# 2022-01-05 00:00:00-05:00  144.18  144.30  137.52  137.65     137.65  49642000
# 2022-01-06 00:00:00-05:00  137.50  139.69  136.76  137.55     137.55  29050000
# 2022-01-07 00:00:00-05:00  137.90  138.25  135.79  137.00     137.00  19408000
# ...                           ...     ...     ...     ...        ...       ...
# 2022-03-24 00:00:00-04:00  139.27  141.40  138.04  141.31     141.31  20544000
# 2022-03-25 00:00:00-04:00  141.75  141.96  139.70  141.52     141.52  19270000
# 2022-03-28 00:00:00-04:00  140.68  141.98  139.83  141.95     141.95  23774000
# 2022-03-29 00:00:00-04:00  143.16  144.16  142.48  143.25     143.25  28678000
# 2022-03-30 00:00:00-04:00  142.87  143.48  142.17  142.64     142.64  21046000
#
# [61 rows x 6 columns]

# %% [markdown]
# ## 🔹 <font color="DeepPink">**A divertirse... 😃**</font>

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Crear una columna que se llame Name, y colocar como valor el nombre de la acción, es decir, su símbolo (denominación que usamos en el parámetro de la función para obtener los datos remotos)...**
# </font>
# </p>

# %%
MSFT["Name"] = "MSFT"

# %%
AAPL["Name"] = "AAPL"

# %%
GOOG["Name"] = "GOOG"

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Concatenar los tres dataframes... usando el metodo de pandas ```concat()```**
# </font>
# </p>

# %%
ACCIONES = pd.concat([MSFT, AAPL, GOOG])

# %%
ACCIONES
# Out:
#                              Open    High     Low   Close  Adj Close  \
# Date
# 2022-01-03 00:00:00-05:00  335.35  338.00  329.78  334.75     331.64
# 2022-01-04 00:00:00-05:00  334.83  335.20  326.12  329.01     325.96
# 2022-01-05 00:00:00-05:00  325.86  326.07  315.98  316.38     313.44
# 2022-01-06 00:00:00-05:00  313.15  318.70  311.49  313.88     310.97
# 2022-01-07 00:00:00-05:00  314.15  316.50  310.09  314.04     311.12
# ...                           ...     ...     ...     ...        ...
# 2022-03-24 00:00:00-04:00  139.27  141.40  138.04  141.31     141.31
# 2022-03-25 00:00:00-04:00  141.75  141.96  139.70  141.52     141.52
# 2022-03-28 00:00:00-04:00  140.68  141.98  139.83  141.95     141.95
# 2022-03-29 00:00:00-04:00  143.16  144.16  142.48  143.25     143.25
# 2022-03-30 00:00:00-04:00  142.87  143.48  142.17  142.64     142.64
#
#                              Volume  Name
# Date
# 2022-01-03 00:00:00-05:00  28865100  MSFT
# 2022-01-04 00:00:00-05:00  32674300  MSFT
# 2022-01-05 00:00:00-05:00  40054300  MSFT
# 2022-01-06 00:00:00-05:00  39646100  MSFT
# 2022-01-07 00:00:00-05:00  32720000  MSFT
# ...                             ...   ...
# 2022-03-24 00:00:00-04:00  20544000  GOOG
# 2022-03-25 00:00:00-04:00  19270000  GOOG
# 2022-03-28 00:00:00-04:00  23774000  GOOG
# 2022-03-29 00:00:00-04:00  28678000  GOOG
# 2022-03-30 00:00:00-04:00  21046000  GOOG
#
# [183 rows x 7 columns]

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Del dataframe resultante, dejar solo las columnas ```Close``` y ```Name```...**
# </font>
# </p>

# %%
ACCIONES.drop(columns=["Open","High","Low","Adj Close","Volume"], inplace=True)

# %%
ACCIONES
# Out:
#                             Close  Name
# Date
# 2022-01-03 00:00:00-05:00  334.75  MSFT
# 2022-01-04 00:00:00-05:00  329.01  MSFT
# 2022-01-05 00:00:00-05:00  316.38  MSFT
# 2022-01-06 00:00:00-05:00  313.88  MSFT
# 2022-01-07 00:00:00-05:00  314.04  MSFT
# ...                           ...   ...
# 2022-03-24 00:00:00-04:00  141.31  GOOG
# 2022-03-25 00:00:00-04:00  141.52  GOOG
# 2022-03-28 00:00:00-04:00  141.95  GOOG
# 2022-03-29 00:00:00-04:00  143.25  GOOG
# 2022-03-30 00:00:00-04:00  142.64  GOOG
#
# [183 rows x 2 columns]

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Al dataframe resultante, agregar una columna denominada ```Date``` con los valores del índice...**
# </font>
# </p>

# %%
ACCIONES.reset_index(inplace=True)

# %%
ACCIONES
# Out:
#                          Date   Close  Name
# 0   2022-01-03 00:00:00-05:00  334.75  MSFT
# 1   2022-01-04 00:00:00-05:00  329.01  MSFT
# 2   2022-01-05 00:00:00-05:00  316.38  MSFT
# 3   2022-01-06 00:00:00-05:00  313.88  MSFT
# 4   2022-01-07 00:00:00-05:00  314.04  MSFT
# ..                        ...     ...   ...
# 178 2022-03-24 00:00:00-04:00  141.31  GOOG
# 179 2022-03-25 00:00:00-04:00  141.52  GOOG
# 180 2022-03-28 00:00:00-04:00  141.95  GOOG
# 181 2022-03-29 00:00:00-04:00  143.25  GOOG
# 182 2022-03-30 00:00:00-04:00  142.64  GOOG
#
# [183 rows x 3 columns]

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Verificar los tipos de datos de las columnas del dataframe...**
# </font>
# </p>

# %%
ACCIONES.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    183 non-null    datetime64[ns, America/New_York]
#  1   Close   183 non-null    float64
#  2   Name    183 non-null    object
# dtypes: datetime64[ns, America/New_York](1), float64(1), object(1)
# memory usage: 4.4+ KB

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Un poco más dificil... 😈**</font>

# %% [markdown]
# ---
# <p>
# <font color="DeepPink">
#
# 👀 **Para los siguientes puntos se puede consultar la documentación técnica de Pandas, la de Plotly, y la que necesiten...** 😃
# </font>
# </p>
#
# ---

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Cambiar los formatos del tipo de dato fecha..., para que quede año, mes y día...**
# </font>
# </p>

# %% [markdown]
# https://es.stackoverflow.com/questions/480149/como-quitar-hora-a-fecha-en-pandas

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.html

# %%
ACCIONES["Date"] = pd.to_datetime(ACCIONES.Date.dt.date)

# %%
ACCIONES
# Out:
#           Date   Close  Name
# 0   2022-01-03  334.75  MSFT
# 1   2022-01-04  329.01  MSFT
# 2   2022-01-05  316.38  MSFT
# 3   2022-01-06  313.88  MSFT
# 4   2022-01-07  314.04  MSFT
# ..         ...     ...   ...
# 178 2022-03-24  141.31  GOOG
# 179 2022-03-25  141.52  GOOG
# 180 2022-03-28  141.95  GOOG
# 181 2022-03-29  143.25  GOOG
# 182 2022-03-30  142.64  GOOG
#
# [183 rows x 3 columns]

# %%
ACCIONES.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    183 non-null    datetime64[ns]
#  1   Close   183 non-null    float64
#  2   Name    183 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 4.4+ KB

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Hacer un gráfico lineal que muestre todas las acciones...**
# </font>
# </p>

# %%
px.line(ACCIONES, 
        x="Date", 
        y="Close", 
        color="Name",
        title='Acciones de Microsoft, Apple y Google',
        template="gridon",
        markers=True,
        hover_name="Name")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.0.min.js"></script>                <div id="8ec04da1-8e3c-4a6b-a1ee-aea283c953f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ec04da1-8e3c-4a6b-a1ee-aea283c953f8")) {                    Plotly.newPlot(                        "8ec04da1-8e3c-4a6b-a1ee-aea283c953f8",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Name=MSFT<br>Date=%{x}<br>Close=%{y}<extra></extra>","hovertext":["MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT","MSFT"],"legendgroup":"MSFT","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"MSFT","orientation":"v","showlegend":true,"x":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00"],"xaxis":"x","y":[334.75,329.01,316.38,313.88,314.04,314.27,314.98,318.27,304.8,310.2,302.65,303.33,301.6,296.03,296.37,288.49,296.71,299.84,308.26,310.98,308.76,313.46,301.25,305.94,300.95,304.56,311.21,302.38,295.04,295.0,300.47,299.5,290.73,287.93,287.72,280.27,294.59,297.31,298.79,294.95,300.19,295.92,289.86,278.91,275.85,288.5,285.59,280.07,276.44,287.15,294.39,295.22,300.43,299.16,304.06,299.49,304.1,303.68,310.7,315.41,313.86],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Name=AAPL<br>Date=%{x}<br>Close=%{y}<extra></extra>","hovertext":["AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL","AAPL"],"legendgroup":"AAPL","line":{"color":"#FF7F0E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"AAPL","orientation":"v","showlegend":true,"x":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","202 ...

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Hacer un boxplot... para cada acción... y en lo posible visualizar también los puntos en el mismo gráfico...**
# </font>
# </p>

# %%
ACCIONES.head()
# Out:
#         Date   Close  Name
# 0 2022-01-03  334.75  MSFT
# 1 2022-01-04  329.01  MSFT
# 2 2022-01-05  316.38  MSFT
# 3 2022-01-06  313.88  MSFT
# 4 2022-01-07  314.04  MSFT

# %%
MSFT = ACCIONES.query("Name == 'MSFT'")

# %%
px.box(MSFT, 
       y = "Close",
       template = "gridon",
       color = "Name",
       title = "Microsoft",
       points="all",
       hover_name="Date")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.0.min.js"></script>                <div id="b1e112d1-2428-4876-8839-5af2cf34bbe8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1e112d1-2428-4876-8839-5af2cf34bbe8")) {                    Plotly.newPlot(                        "b1e112d1-2428-4876-8839-5af2cf34bbe8",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"<b>%{hovertext}</b><br><br>Name=MSFT<br>Close=%{y}<extra></extra>","hovertext":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00"],"legendgroup":"MSFT","marker":{"color":"#1F77B4"},"name":"MSFT","notched":false,"offsetgroup":"MSFT","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[334.75,329.01,316.38,313.88,314.04,314.27,314.98,318.27,304.8,310.2,302.65,303.33,301.6,296.03,296.37,288.49,296.71,299.84,308.26,310.98,308.76,313.46,301.25,305.94,300.95,304.56,311.21,302.38,295.04,295.0,300.47,299.5,290.73,287.93,287.72,280.27,294.59,297.31,298.79,294.95,300.19,295.92,289.86,278.91,275.85,288.5,285.59,280.07,276.44,287.15,294.39,295.22,300.43,299.16,304.06,299.49,304.1,303.68,310.7,315.41,313.86],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0]},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Close"}},"legend":{"title":{"text":"Name"},"tracegroupgap":0},"title":{"text":"Microsoft"},"boxmode":"group"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('b1e112d1-2428-4876-8839-5af2cf34bbe8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %%
AAPL = ACCIONES.query("Name == 'AAPL'")

# %%
px.box(AAPL, 
       y = "Close",
       template = "gridon",
       color = "Name",
       title = "Apple",
       points="all",
       hover_name="Date")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.0.min.js"></script>                <div id="f5cd04d8-0d1e-4850-9f2f-4d143f1c08ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5cd04d8-0d1e-4850-9f2f-4d143f1c08ed")) {                    Plotly.newPlot(                        "f5cd04d8-0d1e-4850-9f2f-4d143f1c08ed",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"<b>%{hovertext}</b><br><br>Name=AAPL<br>Close=%{y}<extra></extra>","hovertext":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00"],"legendgroup":"AAPL","marker":{"color":"#1F77B4"},"name":"AAPL","notched":false,"offsetgroup":"AAPL","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[182.01,179.7,174.92,172.0,172.17,172.19,175.08,175.53,172.19,173.07,169.8,166.23,164.51,162.41,161.62,159.78,159.69,159.22,170.33,174.78,174.61,175.84,172.9,172.39,171.66,174.83,176.28,172.12,168.64,168.88,172.79,172.55,168.88,167.3,164.32,160.07,162.74,164.85,165.12,163.2,166.56,166.23,163.17,159.3,157.44,162.95,158.52,154.73,150.62,155.09,159.59,160.62,163.98,165.38,168.82,170.21,174.07,174.72,175.6,178.96,177.77],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0]},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Close"}},"legend":{"title":{"text":"Name"},"tracegroupgap":0},"title":{"text":"Apple"},"boxmode":"group"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('f5cd04d8-0d1e-4850-9f2f-4d143f1c08ed');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %%
GOOG = ACCIONES.query("Name == 'GOOG'")

# %%
px.box(GOOG, 
       y = "Close",
       template = "gridon",
       color = "Name",
       title = "Google",
       points="all",
       hover_name="Date")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.0.min.js"></script>                <div id="c95f585f-5c78-4b6f-98a7-bf9e68f47cb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c95f585f-5c78-4b6f-98a7-bf9e68f47cb4")) {                    Plotly.newPlot(                        "c95f585f-5c78-4b6f-98a7-bf9e68f47cb4",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"<b>%{hovertext}</b><br><br>Name=GOOG<br>Close=%{y}<extra></extra>","hovertext":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00"],"legendgroup":"GOOG","marker":{"color":"#1F77B4"},"name":"GOOG","notched":false,"offsetgroup":"GOOG","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[145.07,144.42,137.65,137.55,137.0,138.57,140.02,141.65,139.13,139.79,136.29,135.65,133.51,130.09,130.37,126.74,129.24,129.12,133.29,135.7,137.88,148.04,142.65,143.02,138.94,139.21,141.45,138.6,134.13,135.3,136.43,137.49,132.31,130.47,129.4,127.58,132.67,134.52,134.89,134.17,134.75,134.31,132.12,126.46,127.28,133.87,132.68,130.48,126.74,129.66,133.69,134.6,136.8,136.48,140.28,138.5,141.31,141.52,141.95,143.25,142.64],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0]},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Close"}},"legend":{"title":{"text":"Name"},"tracegroupgap":0},"title":{"text":"Google"},"boxmode":"group"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('c95f585f-5c78-4b6f-98a7-bf9e68f47cb4');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Ahora hacer un boxplot... para todas las acciones... y en lo posible visualizar también los puntos en el mismo gráfico...**
# </font>
# </p>

# %%
px.box(ACCIONES, 
       y = "Close",
       template = "gridon",
       color = "Name",
       title = "Microsoft, Apple y Google",
       points="all",
       hover_name="Date")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.0.min.js"></script>                <div id="690913b7-587e-4818-853f-489b3f4a321f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("690913b7-587e-4818-853f-489b3f4a321f")) {                    Plotly.newPlot(                        "690913b7-587e-4818-853f-489b3f4a321f",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"<b>%{hovertext}</b><br><br>Name=MSFT<br>Close=%{y}<extra></extra>","hovertext":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00"],"legendgroup":"MSFT","marker":{"color":"#1F77B4"},"name":"MSFT","notched":false,"offsetgroup":"MSFT","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[334.75,329.01,316.38,313.88,314.04,314.27,314.98,318.27,304.8,310.2,302.65,303.33,301.6,296.03,296.37,288.49,296.71,299.84,308.26,310.98,308.76,313.46,301.25,305.94,300.95,304.56,311.21,302.38,295.04,295.0,300.47,299.5,290.73,287.93,287.72,280.27,294.59,297.31,298.79,294.95,300.19,295.92,289.86,278.91,275.85,288.5,285.59,280.07,276.44,287.15,294.39,295.22,300.43,299.16,304.06,299.49,304.1,303.68,310.7,315.41,313.86],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"<b>%{hovertext}</b><br><br>Name=AAPL<br>Close=%{y}<extra></extra>","hovertext":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00"," ...
#
# var gd = document.getElementById('690913b7-587e-4818-853f-489b3f4a321f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display =

# %% [markdown]
# <p>
# <font color="Red">
#
# > **Y por último, hacer un gráfico financiero de velas... para las acciones de Google...** 😈😈😈
# </font>
# </p>

# %%
GOOG = yf.download("GOOG", start="2022-01-01", end="2022-03-31").round(2)
GOOG.reset_index(inplace=True)
GOOG["Date"] = pd.to_datetime(GOOG.Date.dt.date)
GOOG
# Out:
# [*********************100%***********************]  1 of 1 completed
#          Date    Open    High     Low   Close  Adj Close    Volume
# 0  2022-01-03  144.48  145.55  143.50  145.07     145.07  25214000
# 1  2022-01-04  145.55  146.61  143.82  144.42     144.42  22928000
# 2  2022-01-05  144.18  144.30  137.52  137.65     137.65  49642000
# 3  2022-01-06  137.50  139.69  136.76  137.55     137.55  29050000
# 4  2022-01-07  137.90  138.25  135.79  137.00     137.00  19408000
# ..        ...     ...     ...     ...     ...        ...       ...
# 56 2022-03-24  139.27  141.40  138.04  141.31     141.31  20544000
# 57 2022-03-25  141.75  141.96  139.70  141.52     141.52  19270000
# 58 2022-03-28  140.68  141.98  139.83  141.95     141.95  23774000
# 59 2022-03-29  143.16  144.16  142.48  143.25     143.25  28678000
# 60 2022-03-30  142.87  143.48  142.17  142.64     142.64  21046000
#
# [61 rows x 7 columns]

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(data=[go.Candlestick(x=GOOG["Date"],
                open=GOOG['Open'],
                high=GOOG['High'],
                low=GOOG['Low'],
                close=GOOG['Close'])])

fig.update_layout(template="gridon",
                  title="Cotización de Google")


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.0.min.js"></script>                <div id="08c35627-08e4-4a90-88bf-1ccd15b6f1d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08c35627-08e4-4a90-88bf-1ccd15b6f1d7")) {                    Plotly.newPlot(                        "08c35627-08e4-4a90-88bf-1ccd15b6f1d7",                        [{"close":[145.07,144.42,137.65,137.55,137.0,138.57,140.02,141.65,139.13,139.79,136.29,135.65,133.51,130.09,130.37,126.74,129.24,129.12,133.29,135.7,137.88,148.04,142.65,143.02,138.94,139.21,141.45,138.6,134.13,135.3,136.43,137.49,132.31,130.47,129.4,127.58,132.67,134.52,134.89,134.17,134.75,134.31,132.12,126.46,127.28,133.87,132.68,130.48,126.74,129.66,133.69,134.6,136.8,136.48,140.28,138.5,141.31,141.52,141.95,143.25,142.64],"high":[145.55,146.61,144.3,139.69,138.25,138.64,140.33,142.81,143.19,141.2,137.39,138.4,137.91,134.76,130.78,129.34,132.81,132.61,133.37,135.84,138.2,152.1,149.12,144.54,143.85,139.84,142.18,141.43,139.28,136.17,137.9,137.95,136.84,133.82,131.9,131.75,133.04,135.39,135.64,136.11,135.62,136.71,134.2,131.9,131.25,134.2,133.54,134.2,131.03,130.52,133.77,134.74,136.91,137.58,141.5,140.02,141.4,141.96,141.98,144.16,143.48],"low":[143.5,143.82,137.52,136.76,135.79,133.14,136.81,141.11,138.91,137.5,135.62,135.5,133.14,130.0,124.64,126.38,127.15,128.95,128.69,132.27,134.57,145.56,142.21,139.82,138.7,136.87,140.38,138.05,133.29,133.3,135.54,134.82,132.2,130.31,127.74,127.5,124.76,131.76,132.83,133.38,133.43,133.43,130.41,126.41,125.86,130.09,131.4,130.3,126.41,126.57,129.2,132.72,132.93,134.61,136.5,138.17,138.04,139.7,139.83,142.48,142.17],"open":[144.48,145.55,144.18,137.5,137.9,135.1,138.18,141.55,141.84,137.5,136.6,136.94,136.51,133.01,126.03,128.44,130.59,131.36,130.0,134.2,137.84,151.86,145.29,143.02,143.71,138.99,140.85,139.5,138.75,133.37,137.47,136.43,136.15,133.04,129.99,131.08,125.0,133.53,133.28,134.48,134.61,135.98,133.38,131.9,126.25,131.4,131.46,134.0,130.57,127.74,131.0,133.32,133.88,136.85,136.5,139.14,139.27,141.75,140.68,143.16,142.87],"x":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00"],"type":"candlestick"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"title":{"text":"Cotizaci\u00f3n de Google"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('08c35627-08e4-4a90-88bf-1ccd15b6f1d7');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# <br>
# <br>
# <p align="center"><b>
# 💗
# <font color="DeepPink">
# Hemos llegado al final de nuestro colab, a seguir codeando...
# </font>
# </p>
# <br>
# <p align="center">
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20BDS%20Horizontal%208.png?raw=true">
# </p>
#
# ---
