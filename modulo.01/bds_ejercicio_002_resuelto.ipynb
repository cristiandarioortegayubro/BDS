# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/BDS/blob/main/modulo.01/bds_ejercicio_002_resuelto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20BDS%20Horizontal%208.png?raw=true">
# </p>

# %% [markdown]
# <p align="center">
# <img src="https://www.python.org/static/community_logos/python-powered-h-70x91.png">
# </p>

# %% [markdown]
# # ☯ <font color="DeepPink">**Actividad 002**</font>

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Habilitando pandas**</font>

# %%
import pandas as pd

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Datos**</font>

# %%
datos = "https://raw.githubusercontent.com/cristiandarioortegayubro/base/main/dataset/departamento.csv"

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Creación del DataFrame**</font>

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Generar el dataframe**
# </font>
# </p>

# %%
departamentos = pd.read_csv(datos)
departamentos
# Out:
#        M2  AMBIENTES  ANTIGUEDAD  BAÑOS    LATITUD   LONGITUD     COMUNA  \
# 0      81          3           4      1 -34.581078 -58.449433  COMUNA 13
# 1      69          3          20      1 -34.623129 -58.439338  COMUNA 06
# 2      75          3          20      1 -34.604972 -58.421278  COMUNA 05
# 3      42          2          40      1 -34.604725 -58.399524  COMUNA 03
# 4      90          3           1      1 -34.623390 -58.504401  COMUNA 10
# ...   ...        ...         ...    ...        ...        ...        ...
# 2227   88          4          20      2 -34.550152 -58.470136  COMUNA 13
# 2228   35          1          35      1 -34.602256 -58.429315  COMUNA 05
# 2229  117          3          10      2 -34.620314 -58.365451  COMUNA 01
# 2230   69          4          40      1 -34.628533 -58.427748  COMUNA 07
# 2231   73          4          50      2 -34.596659 -58.378396  COMUNA 01
#
#       DOLARES
# 0      225000
# 1      140000
# 2      154000
# 3       75000
# ...

# %% [markdown]
# ## 🔹 <font color="DeepPink">**A divertirse... 😃**</font>

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Visualizar solamente la columna (serie) dolares... y creamos esa serie...**
# </font>
# </p>

# %%
dolares = departamentos.DOLARES
dolares
# Out:
# 0       225000
# 1       140000
# 2       154000
# 3        75000
# 4       149900
#          ...
# 2227    165000
# 2228     79900
# 2229    520000
# 2230    132000
# 2231    179000
# Name: DOLARES, Length: 2232, dtype: int64

# %%
type(dolares)
# Out:
# pandas.core.series.Series

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Buscamos pasar la serie anterior a dataframe...usando el metodo ```to.frame()```**
# </font>
# </p>

# %%
dolares = pd.Series.to_frame(dolares)
dolares
# Out:
#       DOLARES
# 0      225000
# 1      140000
# 2      154000
# 3       75000
# 4      149900
# ...       ...
# 2227   165000
# 2228    79900
# 2229   520000
# 2230   132000
# 2231   179000
#
# [2232 rows x 1 columns]

# %%
type(dolares)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Mostrar en pantalla ```print()``` los $m^2$ de los departamentos...**
# </font>
# </p>

# %%
departamentos.head()
# Out:
#    M2  AMBIENTES  ANTIGUEDAD  BAÑOS    LATITUD   LONGITUD     COMUNA  DOLARES
# 0  81          3           4      1 -34.581078 -58.449433  COMUNA 13   225000
# 1  69          3          20      1 -34.623129 -58.439338  COMUNA 06   140000
# 2  75          3          20      1 -34.604972 -58.421278  COMUNA 05   154000
# 3  42          2          40      1 -34.604725 -58.399524  COMUNA 03    75000
# 4  90          3           1      1 -34.623390 -58.504401  COMUNA 10   149900

# %%
indice = input('Ingrese el número de departamento: ')
m2 = departamentos.loc[int(indice),'M2']
print("")
print(f" El departamento {indice} tiene {m2} metros cuadrados")
# Out:
# Ingrese el número de departamento: 2
#
#  El departamento 2 tiene 75 metros cuadrados

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Crear una nueva columna llamada PAIS y rellenarla con "Argentina"...**
# </font>
# </p>

# %%
departamentos.loc[:,"PAIS"] = "Argentina"

# %%
departamentos.head()
# Out:
#    M2  AMBIENTES  ANTIGUEDAD  BAÑOS    LATITUD   LONGITUD     COMUNA  DOLARES  \
# 0  81          3           4      1 -34.581078 -58.449433  COMUNA 13   225000
# 1  69          3          20      1 -34.623129 -58.439338  COMUNA 06   140000
# 2  75          3          20      1 -34.604972 -58.421278  COMUNA 05   154000
# 3  42          2          40      1 -34.604725 -58.399524  COMUNA 03    75000
# 4  90          3           1      1 -34.623390 -58.504401  COMUNA 10   149900
#
#         PAIS
# 0  Argentina
# 1  Argentina
# 2  Argentina
# 3  Argentina
# 4  Argentina

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Ahora una nueva columna llamada CONTINENTE y rellenarla con "America"...**
# </font>
# </p>

# %%
departamentos["CONTINENTE"] = "America"

# %%
departamentos.head()
# Out:
#    M2  AMBIENTES  ANTIGUEDAD  BAÑOS    LATITUD   LONGITUD     COMUNA  DOLARES  \
# 0  81          3           4      1 -34.581078 -58.449433  COMUNA 13   225000
# 1  69          3          20      1 -34.623129 -58.439338  COMUNA 06   140000
# 2  75          3          20      1 -34.604972 -58.421278  COMUNA 05   154000
# 3  42          2          40      1 -34.604725 -58.399524  COMUNA 03    75000
# 4  90          3           1      1 -34.623390 -58.504401  COMUNA 10   149900
#
#         PAIS CONTINENTE
# 0  Argentina    America
# 1  Argentina    America
# 2  Argentina    America
# 3  Argentina    America
# 4  Argentina    America

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Generar una columna que se llame PESOS cuyo valor sea DOLARES $\times$ $300$...**
# </font>
# </p>

# %%
dolar = 300
departamentos["PESOS"] = departamentos["DOLARES"] * dolar
departamentos.head()
# Out:
#    M2  AMBIENTES  ANTIGUEDAD  BAÑOS    LATITUD   LONGITUD     COMUNA  DOLARES  \
# 0  81          3           4      1 -34.581078 -58.449433  COMUNA 13   225000
# 1  69          3          20      1 -34.623129 -58.439338  COMUNA 06   140000
# 2  75          3          20      1 -34.604972 -58.421278  COMUNA 05   154000
# 3  42          2          40      1 -34.604725 -58.399524  COMUNA 03    75000
# 4  90          3           1      1 -34.623390 -58.504401  COMUNA 10   149900
#
#         PAIS CONTINENTE     PESOS
# 0  Argentina    America  67500000
# 1  Argentina    America  42000000
# 2  Argentina    America  46200000
# 3  Argentina    America  22500000
# 4  Argentina    America  44970000

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Mostrar el resumen estadistico descriptivo del dataframe...**
# </font>
# </p>

# %%
departamentos.describe().round(2)
# Out:
#             M2  AMBIENTES  ANTIGUEDAD    BAÑOS  LATITUD  LONGITUD     DOLARES  \
# count  2232.00    2232.00     2232.00  2232.00  2232.00   2232.00     2232.00
# mean     79.40       2.81       24.63     1.43   -34.59    -58.43   206014.01
# std      58.98       1.11       18.41     0.72     0.02      0.03   186368.30
# min      15.00       1.00        1.00     1.00   -34.68    -58.53     7428.00
# 25%      44.00       2.00        9.00     1.00   -34.61    -58.45    98375.00
# 50%      64.00       3.00       20.00     1.00   -34.59    -58.42   146000.00
# 75%      90.00       3.00       40.00     2.00   -34.58    -58.40   235750.00
# max     730.00      10.00      110.00     6.00   -34.54    -58.35  1800000.00
#
#               PESOS
# count  2.232000e+03
# mean   6.180420e+07
# std    5.591049e+07
# min    2.228400e+06
# 25%    2.951250e+07
# 50%    4.380000e+07
# 75%    7.072500e+07
# max    5.400000e+08

# %%
departamentos.describe().round(2).T
# Out:
#              count         mean          std         min          25%  \
# M2          2232.0        79.40        58.98       15.00        44.00
# AMBIENTES   2232.0         2.81         1.11        1.00         2.00
# ANTIGUEDAD  2232.0        24.63        18.41        1.00         9.00
# BAÑOS       2232.0         1.43         0.72        1.00         1.00
# LATITUD     2232.0       -34.59         0.02      -34.68       -34.61
# LONGITUD    2232.0       -58.43         0.03      -58.53       -58.45
# DOLARES     2232.0    206014.01    186368.30     7428.00     98375.00
# PESOS       2232.0  61804203.63  55910491.15  2228400.00  29512500.00
#
#                     50%          75%           max
# M2                64.00        90.00  7.300000e+02
# AMBIENTES          3.00         3.00  1.000000e+01
# ANTIGUEDAD        20.00        40.00  1.100000e+02
# BAÑOS              1.00         2.00  6.000000e+00
# LATITUD          -34.59       -34.58 -3.454000e+01
# ...

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **¿Cual es la media de latitud y longitud?...**
# </font>
# </p>

# %%
descriptivo = departamentos.describe()

# %%
latitud = descriptivo.loc["mean","LATITUD"].round(2)
longitud = descriptivo.loc["mean","LONGITUD"].round(2)

# %%
print(f"La media de las propiedades en latitud es {latitud} y la longitud {longitud}")
# Out:
# La media de las propiedades en latitud es -34.59 y la longitud -58.43

# %% [markdown]
# ## 🔹 <font color="DeepPink">**Un poco más dificil... 😈**</font>

# %% [markdown]
# ---
# <p>
# <font color="DeepPink">
#
# 👀 **Para los siguientes puntos se puede consultar la documentación técnica de Pandas...**
# </font>
# </p>
#
# ---

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **Verificar si existen datos nulos en el dataframe...**
# </font>
# </p>

# %%
departamentos.head()
# Out:
#    M2  AMBIENTES  ANTIGUEDAD  BAÑOS    LATITUD   LONGITUD     COMUNA  DOLARES  \
# 0  81          3           4      1 -34.581078 -58.449433  COMUNA 13   225000
# 1  69          3          20      1 -34.623129 -58.439338  COMUNA 06   140000
# 2  75          3          20      1 -34.604972 -58.421278  COMUNA 05   154000
# 3  42          2          40      1 -34.604725 -58.399524  COMUNA 03    75000
# 4  90          3           1      1 -34.623390 -58.504401  COMUNA 10   149900
#
#         PAIS CONTINENTE     PESOS
# 0  Argentina    America  67500000
# 1  Argentina    America  42000000
# 2  Argentina    America  46200000
# 3  Argentina    America  22500000
# 4  Argentina    America  44970000

# %%
departamentos.isnull().sum()
# Out:
# M2            0
# AMBIENTES     0
# ANTIGUEDAD    0
# BAÑOS         0
# LATITUD       0
# LONGITUD      0
# COMUNA        0
# DOLARES       0
# PAIS          0
# CONTINENTE    0
# PESOS         0
# dtype: int64

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **¿Cuantos departamentos hay por comuna?...**
# </font>
# </p>

# %%
departamentos.COMUNA.value_counts()
# Out:
# COMUNA 14    375
# COMUNA 13    320
# COMUNA 02    305
# COMUNA 01    239
# COMUNA 05    191
# COMUNA 03    161
# COMUNA 06    138
# COMUNA 12    138
# COMUNA 15    126
# COMUNA 07     77
# COMUNA 11     61
# COMUNA 04     54
# COMUNA 10     31
# COMUNA 09     12
# COMUNA 08      4
# Name: COMUNA, dtype: int64

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# > **¿Cuantos ambientes tiene los departamentos de la comuna 14?...**
# </font>
# </p>

# %%
departamentos.loc[departamentos.COMUNA == "COMUNA 14","AMBIENTES"].value_counts()
# Out:
# 2    130
# 3    106
# 4     65
# 5     38
# 1     32
# 6      4
# Name: AMBIENTES, dtype: int64

# %% [markdown]
# <br>
# <br>
# <p align="center"><b>
# 💗
# <font color="DeepPink">
# Hemos llegado al final de nuestro colab, a seguir codeando...
# </font>
# </p>
# <br>
# <p align="center">
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20BDS%20Horizontal%208.png?raw=true">
# </p>
#
# ---
