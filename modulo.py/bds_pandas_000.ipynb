# %% [markdown]
# <a href="https://colab.research.google.com/github/cristiandarioortegayubro/BDS/blob/main/modulo.py/bds_pandas_000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo](https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20BDS%20Horizontal%208.png?raw=true)

# %% [markdown]
# ![](https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20Pandas.png?raw=true)

# %% [markdown]
# <b>
# <p>
# <font color="DeepPink">
#
# 💗 En este notebook se desarrollarán algunos conceptos para empezar a recordar nuestra experiencia con Pandas. El objetivo de este notebook es traer los datos de la página web de la Administración Tributaria Mendoza, y generar un dataframe con la recaudación impositiva anual.
#
# 👀 Antes que nada, verificamos la versión de Python con la cual estamos trabajando...
# </font>
# </p>
# </b>

# %%
# !python3 -V
# Out:
# Python 3.8.16

# %% [markdown]
#  # **<font color="DeepPink">Algo más que 10 minutos...</font>**

# %% [markdown]
# ## **<font color="DeepPink">Habilitando bibliotecas de análisis de datos...</font>**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# https://pandas.pydata.org/

# %% [markdown]
# ## **<font color="DeepPink">Obtención de datos</font>**

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# **Buscamos la página web en donde se encuentran los datos que queremos adquirir. Luego, al objeto ```data``` le asignamos la dirección URL de la página web de la Administración Tributaria Mendoza.**
#
# </font>
# </p>

# %% [markdown]
# https://www.atm.mendoza.gov.ar/portalatm/zoneBottom/datosInteres/recaudacion/recaudacion_por_impuesto_anual.jsp

# %%
data = "https://www.atm.mendoza.gov.ar/portalatm/zoneBottom/datosInteres/recaudacion/recaudacion_por_impuesto_anual.jsp"

# %% [markdown]
# ## **<font color="DeepPink">Creando un dataframe</font>**

# %% [markdown]
# ### **<font color="DeepPink">Leyendo los datos</font>**

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# **Utilizamos el método de Pandas ```read_html()``` para leer los datos de la página web, y utilizamos los parámetros ```index_col=0``` y ```header=1``` para hacer un poco legigle los datos...**
#
# </font>
# </p>

# %%
df = pd.read_html(data, flavor="html5lib", index_col=0, header=1)

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# **Se procede a verificar el objeto creado con el método ```type()```...**
#
# </font>
# </p>

# %%
type(df)
# Out:
# list

# %% [markdown]
# ### **<font color="DeepPink">Visualizando los datos</font>**

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# **Verificamos la cantidad de elementos que tiene la lista con el método ```len()``` y luego, llamamos al objeto ```df``` para ver los datos...**
#
# </font>
# </p>

# %%
len(df)
# Out:
# 23

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# **El objeto tiene $23$ elementos, que corresponden a las diferentes tablas con las recaudaciones de los impuestos por año fiscal, desde el año $2000$ hasta el año $2022$...**
#
# </font>
# </p>

# %% [markdown]
# ### **<font color="DeepPink">Dando el formato de dataframe</font>**

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# **Primero vamos a visualizar el último elemento de la lista, ya sabiendo que la lista posee $23$ elementos, entonces llamamos al último...**
#
# </font>
# </p>

# %%
df[22]
# Out:
#            Impuestos 2000 - 2022 Impuestos 2000 - 2022.1  \
# 2022
# NaN              Ingresos Varios         Ingresos Brutos
# NaN                          NaN                     NaN
# Enero                  179013389              6815275641
# NaN                          NaN                     NaN
# Febrero                223999109              6525087915
# NaN                          NaN                     NaN
# Marzo                  218445045              6633613415
# NaN                          NaN                     NaN
# Abril               233420590.92            7882943560.5
# NaN                          NaN                     NaN
# Mayo                   260269325              8485148694
# NaN                          NaN                     NaN
# Junio                  243073675              8272230858
# NaN                          NaN                     NaN
# Julio                  187551741              9777144943
# NaN                          NaN                     NaN
# Agosto                 214209657             10673847335
# NaN                          NaN                     NaN
# Septiembre             220741077             10903034059
# NaN                          NaN                     NaN
# Octubre                203839854             11468663772
# NaN                          NaN                     NaN
# Noviembre              221138770             12420675590
# NaN                          NaN                     NaN
# Diciembre                    NaN                     NaN
# NaN                          NaN                     NaN
# Totales            2405702232.92           99857665782.5
#
#            Impuestos 2000 - 2022.2 Impuestos 2000 - 2022.3  \
# 2022
# NaN                   Inmobiliario               Automotor
# NaN                            NaN                     NaN
# Enero                     83236124               277734375
# NaN                            NaN                     NaN
# Febrero                  327088196              2165283816
# NaN                            NaN                     NaN
# Marzo                   1377477738               675398064
# NaN                            NaN                     NaN
# Abril                 214670297.57            925755849.22
# NaN                            NaN                     NaN
# Mayo                     429439154               511257271
# NaN                            NaN                     NaN
# Junio                    192503829               986531047
# NaN                            NaN                     NaN
# Julio                    423569483               562866368
# NaN                            NaN                     NaN
# Agosto                   208783168              1051893523
# NaN                            NaN                     NaN
# Septiembre               454538851               539079630
# NaN                            NaN                     NaN
# Octubre                  212987319               497258187
# NaN                            NaN                     NaN
# Noviembre                464892777               532424814
# NaN                            NaN                     NaN
# Diciembre                      NaN                     NaN
# NaN                            NaN                     NaN
# Totales              4389186936.57           8725482944.22
#
#            Impuestos 2000 - 2022.4  Impuestos 2000 - 2022.5  \
# 2022
# NaN                         Sellos                      NaN
# NaN                            NaN                      NaN
# Enero                    960633347                      NaN
# NaN                            NaN                      NaN
# Febrero                  851884008                      NaN
# NaN                            NaN                      NaN
# Marzo                    810314736                      NaN
# NaN                            NaN                      NaN
# Abril                 952296514.58                      NaN
# NaN                            NaN                      NaN
# Mayo                    1083550836                      NaN
# NaN                            NaN                      NaN
# Junio                   1081415464                      NaN
# NaN                            NaN                      NaN
# Julio                   1138253314                      NaN
# NaN                            NaN                      NaN
# Agosto                  1189081026                      NaN
# NaN                            NaN                      NaN
# Septiembre              1405661757                      NaN
# NaN                            NaN                      NaN
# Octubre                 1211572656                      NaN
# NaN                            NaN                      NaN
# Noviembre               1275325918                      NaN
# NaN                            NaN                      NaN
# Diciembre                      NaN                      NaN
# NaN                            NaN                      NaN
# Totales             11959989576.58                      NaN
#
#             Impuestos 2000 - 2022.6  Impuestos 2000 - 2022.7  \
# 2022
# NaN                             NaN                      NaN
# NaN                             NaN                      NaN
# Enero                           NaN                      NaN
# NaN                             NaN                      NaN
# Febrero                         NaN                      NaN
# NaN                             NaN                      NaN
# Marzo                           NaN                      NaN
# NaN                             NaN                      NaN
# Abril                           NaN                      NaN
# NaN                             NaN                      NaN
# Mayo                            NaN                      NaN
# NaN                             NaN                      NaN
# Junio                           NaN                      NaN
# NaN                             NaN                      NaN
# Julio                           NaN                      NaN
# NaN                             NaN                      NaN
# Agosto                          NaN                      NaN
# NaN                             NaN                      NaN
# Septiembre                      NaN                      NaN
# NaN                             NaN                      NaN
# Octubre                         NaN                      NaN
# NaN                             NaN                      NaN
# Noviembre                       NaN                      NaN
# NaN                             NaN                      NaN
# Diciembre                       NaN                      NaN
# NaN                             NaN                      NaN
# Totales                         NaN                      NaN
#
#             Impuestos 2000 - 2022.8  Impuestos 2000 - 2022.9  ...  \
# 2022                                                          ...
# NaN                             NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Enero                           NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Febrero                         NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Marzo                           NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Abril                           NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Mayo                            NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Junio                           NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Julio                           NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Agosto                          NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Septiembre                      NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Octubre                         NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Noviembre                       NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Diciembre                       NaN                      NaN  ...
# NaN                             NaN                      NaN  ...
# Totales                         NaN                      NaN  ...
#
#             Impuestos 2000 - 2022.40  Impuestos 2000 - 2022.41  \
# 2022
# NaN                              NaN                       NaN
# NaN                              NaN                       NaN
# Enero                            NaN                       NaN
# NaN                              NaN                       NaN
# Febrero                          NaN                       NaN
# NaN                              NaN                       NaN
# Marzo                            NaN                       NaN
# NaN                              NaN                       NaN
# Abril                            NaN                       NaN
# NaN                              NaN                       NaN
# Mayo                             NaN                       NaN
# NaN                              NaN                       NaN
# Junio                            NaN                       NaN
# NaN                              NaN                       NaN
# Julio                            NaN                       NaN
# NaN                              NaN                       NaN
# Agosto                           NaN                       NaN
# NaN                              NaN                       NaN
# Septiembre                       NaN                       NaN
# NaN                              NaN                       NaN
# Octubre                          NaN                       NaN
# NaN                              NaN                       NaN
# Noviembre                        NaN                       NaN
# NaN                              NaN                       NaN
# Diciembre                        NaN                       NaN
# NaN                              NaN                       NaN
# Totales                          NaN                       NaN
#
#             Impuestos 2000 - 2022.42  Impuestos 2000 - 2022.43  \
# 2022
# NaN                              NaN                       NaN
# NaN                              NaN                       NaN
# Enero                            NaN                       NaN
# NaN                              NaN                       NaN
# Febrero                          NaN                       NaN
# NaN                              NaN                       NaN
# Marzo                            NaN                       NaN
# NaN                              NaN                       NaN
# Abril                            NaN                       NaN
# NaN                              NaN                       NaN
# Mayo                             NaN                       NaN
# NaN                              NaN                       NaN
# Junio                            NaN                       NaN
# NaN                              NaN                       NaN
# Julio                            NaN                       NaN
# NaN                              NaN                       NaN
# Agosto                           NaN                       NaN
# NaN                              NaN                       NaN
# Septiembre                       NaN                       NaN
# NaN                              NaN                       NaN
# Octubre                          NaN                       NaN
# NaN                              NaN                       NaN
# Noviembre                        NaN                       NaN
# NaN                              NaN                       NaN
# Diciembre                        NaN                       NaN
# NaN                              NaN                       NaN
# Totales                          NaN                       NaN
#
#             Impuestos 2000 - 2022.44  Impuestos 2000 - 2022.45  \
# 2022
# NaN                              NaN                       NaN
# NaN                              NaN                       NaN
# Enero                            NaN                       NaN
# NaN                              NaN                       NaN
# Febrero                          NaN                       NaN
# NaN                              NaN                       NaN
# Marzo                            NaN                       NaN
# NaN                              NaN                       NaN
# Abril                            NaN                       NaN
# NaN                              NaN                       NaN
# Mayo                             NaN                       NaN
# NaN                              NaN                       NaN
# Junio                            NaN                       NaN
# NaN                              NaN                       NaN
# Julio                            NaN                       NaN
# NaN                              NaN                       NaN
# Agosto                           NaN                       NaN
# NaN                              NaN                       NaN
# Septiembre                       NaN                       NaN
# NaN                              NaN                       NaN
# Octubre                          NaN                       NaN
# NaN                              NaN                       NaN
# Noviembre                        NaN                       NaN
# NaN                              NaN                       NaN
# Diciembre                        NaN                       NaN
# NaN                              NaN                       NaN
# Totales                          NaN                       NaN
#
#             Impuestos 2000 - 2022.46  Impuestos 2000 - 2022.47  \
# 2022
# NaN                              NaN                       NaN
# NaN                              NaN                       NaN
# Enero                            NaN                       NaN
# NaN                              NaN                       NaN
# Febrero                          NaN                       NaN
# NaN                              NaN                       NaN
# Marzo                            NaN                       NaN
# NaN                              NaN                       NaN
# Abril                            NaN                       NaN
# NaN                              NaN                       NaN
# Mayo                             NaN                       NaN
# NaN                              NaN                       NaN
# Junio                            NaN                       NaN
# NaN                              NaN                       NaN
# Julio                            NaN                       NaN
# NaN                              NaN                       NaN
# Agosto                           NaN                       NaN
# NaN                              NaN                       NaN
# Septiembre                       NaN                       NaN
# NaN                              NaN                       NaN
# Octubre                          NaN                       NaN
# NaN                              NaN                       NaN
# Noviembre                        NaN                       NaN
# NaN                              NaN                       NaN
# Diciembre                        NaN                       NaN
# NaN                              NaN                       NaN
# Totales                          NaN                       NaN
#
#             Impuestos 2000 - 2022.48  Impuestos 2000 - 2022.49
# 2022
# NaN                              NaN                       NaN
# NaN                              NaN                       NaN
# Enero                            NaN                       NaN
# NaN                              NaN                       NaN
# Febrero                          NaN                       NaN
# NaN                              NaN                       NaN
# Marzo                            NaN                       NaN
# NaN                              NaN                       NaN
# Abril                            NaN                       NaN
# NaN                              NaN                       NaN
# Mayo                             NaN                       NaN
# NaN                              NaN                       NaN
# Junio                            NaN                       NaN
# NaN                              NaN                       NaN
# Julio                            NaN                       NaN
# NaN                              NaN                       NaN
# Agosto                           NaN                       NaN
# NaN                              NaN                       NaN
# Septiembre                       NaN                       NaN
# NaN                              NaN                       NaN
# Octubre                          NaN                       NaN
# NaN                              NaN                       NaN
# Noviembre                        NaN                       NaN
# NaN                              NaN                       NaN
# Diciembre                        NaN                       NaN
# NaN                              NaN                       NaN
# Totales                          NaN                       NaN
#
# [27 rows x 50 columns]

# %% [markdown]
# <p>
# <font color="DeepPink">
#
# **El elemento tiene aspecto de dataframe, por lo cual podemos inferir que la lista, es una lista de dataframes, y cada uno de sus elementos es un dataframe correspondiente a cada uno de los años de recaudación, desde el año $2000$ hasta el año $2022$. Por lo tanto, el último elemento de la lista, es el año $2022$.**
#
# </font>
# </p>

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# >***Lo primero que vamos a hacer es eliminar las columnas con datos faltantes...***
# </font>
# </p>

# %%
df = df[22].dropna(axis=1, how="all")

# %%
df
# Out:
#            Impuestos 2000 - 2022 Impuestos 2000 - 2022.1  \
# 2022
# NaN              Ingresos Varios         Ingresos Brutos
# NaN                          NaN                     NaN
# Enero                  179013389              6815275641
# NaN                          NaN                     NaN
# Febrero                223999109              6525087915
# NaN                          NaN                     NaN
# Marzo                  218445045              6633613415
# NaN                          NaN                     NaN
# Abril               233420590.92            7882943560.5
# NaN                          NaN                     NaN
# Mayo                   260269325              8485148694
# NaN                          NaN                     NaN
# Junio                  243073675              8272230858
# NaN                          NaN                     NaN
# Julio                  187551741              9777144943
# NaN                          NaN                     NaN
# Agosto                 214209657             10673847335
# NaN                          NaN                     NaN
# Septiembre             220741077             10903034059
# NaN                          NaN                     NaN
# Octubre                203839854             11468663772
# NaN                          NaN                     NaN
# Noviembre              221138770             12420675590
# NaN                          NaN                     NaN
# Diciembre                    NaN                     NaN
# NaN                          NaN                     NaN
# Totales            2405702232.92           99857665782.5
#
#            Impuestos 2000 - 2022.2 Impuestos 2000 - 2022.3  \
# 2022
# NaN                   Inmobiliario               Automotor
# NaN                            NaN                     NaN
# Enero                     83236124               277734375
# NaN                            NaN                     NaN
# Febrero                  327088196              2165283816
# NaN                            NaN                     NaN
# Marzo                   1377477738               675398064
# NaN                            NaN                     NaN
# Abril                 214670297.57            925755849.22
# NaN                            NaN                     NaN
# Mayo                     429439154               511257271
# NaN                            NaN                     NaN
# Junio                    192503829               986531047
# NaN                            NaN                     NaN
# Julio                    423569483               562866368
# NaN                            NaN                     NaN
# Agosto                   208783168              1051893523
# NaN                            NaN                     NaN
# Septiembre               454538851               539079630
# NaN                            NaN                     NaN
# Octubre                  212987319               497258187
# NaN                            NaN                     NaN
# Noviembre                464892777               532424814
# NaN                            NaN                     NaN
# Diciembre                      NaN                     NaN
# NaN                            NaN                     NaN
# Totales              4389186936.57           8725482944.22
#
#            Impuestos 2000 - 2022.4
# 2022
# NaN                         Sellos
# NaN                            NaN
# Enero                    960633347
# NaN                            NaN
# Febrero                  851884008
# NaN                            NaN
# Marzo                    810314736
# NaN                            NaN
# Abril                 952296514.58
# NaN                            NaN
# Mayo                    1083550836
# NaN                            NaN
# Junio                   1081415464
# NaN                            NaN
# Julio                   1138253314
# NaN                            NaN
# Agosto                  1189081026
# NaN                            NaN
# Septiembre              1405661757
# NaN                            NaN
# Octubre                 1211572656
# NaN                            NaN
# Noviembre               1275325918
# NaN                            NaN
# Diciembre                      NaN
# NaN                            NaN
# Totales             11959989576.58

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# >***Ahora vamos a renombrar las columnas del dataframe, con los datos de la primera fila, que son los impuestos provinciales...***
# </font>
# </p>

# %%
df.columns = df.iloc[0,]

# %%
df
# Out:
# nan         Ingresos Varios  Ingresos Brutos   Inmobiliario      Automotor  \
# 2022
# NaN         Ingresos Varios  Ingresos Brutos   Inmobiliario      Automotor
# NaN                     NaN              NaN            NaN            NaN
# Enero             179013389       6815275641       83236124      277734375
# NaN                     NaN              NaN            NaN            NaN
# Febrero           223999109       6525087915      327088196     2165283816
# NaN                     NaN              NaN            NaN            NaN
# Marzo             218445045       6633613415     1377477738      675398064
# NaN                     NaN              NaN            NaN            NaN
# Abril          233420590.92     7882943560.5   214670297.57   925755849.22
# NaN                     NaN              NaN            NaN            NaN
# Mayo              260269325       8485148694      429439154      511257271
# NaN                     NaN              NaN            NaN            NaN
# Junio             243073675       8272230858      192503829      986531047
# NaN                     NaN              NaN            NaN            NaN
# Julio             187551741       9777144943      423569483      562866368
# NaN                     NaN              NaN            NaN            NaN
# Agosto            214209657      10673847335      208783168     1051893523
# NaN                     NaN              NaN            NaN            NaN
# Septiembre        220741077      10903034059      454538851      539079630
# NaN                     NaN              NaN            NaN            NaN
# Octubre           203839854      11468663772      212987319      497258187
# NaN                     NaN              NaN            NaN            NaN
# Noviembre         221138770      12420675590      464892777      532424814
# NaN                     NaN              NaN            NaN            NaN
# Diciembre               NaN              NaN            NaN            NaN
# NaN                     NaN              NaN            NaN            NaN
# Totales       2405702232.92    99857665782.5  4389186936.57  8725482944.22
#
# nan                 Sellos
# 2022
# NaN                 Sellos
# NaN                    NaN
# Enero            960633347
# NaN                    NaN
# Febrero          851884008
# NaN                    NaN
# Marzo            810314736
# NaN                    NaN
# Abril         952296514.58
# NaN                    NaN
# Mayo            1083550836
# NaN                    NaN
# Junio           1081415464
# NaN                    NaN
# Julio           1138253314
# NaN                    NaN
# Agosto          1189081026
# NaN                    NaN
# Septiembre      1405661757
# NaN                    NaN
# Octubre         1211572656
# NaN                    NaN
# Noviembre       1275325918
# NaN                    NaN
# Diciembre              NaN
# NaN                    NaN
# Totales     11959989576.58

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# >***Vemos que las columnas tienen por nombre ```nan```, vamos a eliminar ese nombre y no dejar ningún nombre a las columnas...***
# </font>
# </p>

# %%
df.columns.name = None

# %%
df
# Out:
#             Ingresos Varios  Ingresos Brutos   Inmobiliario      Automotor  \
# 2022
# NaN         Ingresos Varios  Ingresos Brutos   Inmobiliario      Automotor
# NaN                     NaN              NaN            NaN            NaN
# Enero             179013389       6815275641       83236124      277734375
# NaN                     NaN              NaN            NaN            NaN
# Febrero           223999109       6525087915      327088196     2165283816
# NaN                     NaN              NaN            NaN            NaN
# Marzo             218445045       6633613415     1377477738      675398064
# NaN                     NaN              NaN            NaN            NaN
# Abril          233420590.92     7882943560.5   214670297.57   925755849.22
# NaN                     NaN              NaN            NaN            NaN
# Mayo              260269325       8485148694      429439154      511257271
# NaN                     NaN              NaN            NaN            NaN
# Junio             243073675       8272230858      192503829      986531047
# NaN                     NaN              NaN            NaN            NaN
# Julio             187551741       9777144943      423569483      562866368
# NaN                     NaN              NaN            NaN            NaN
# Agosto            214209657      10673847335      208783168     1051893523
# NaN                     NaN              NaN            NaN            NaN
# Septiembre        220741077      10903034059      454538851      539079630
# NaN                     NaN              NaN            NaN            NaN
# Octubre           203839854      11468663772      212987319      497258187
# NaN                     NaN              NaN            NaN            NaN
# Noviembre         221138770      12420675590      464892777      532424814
# NaN                     NaN              NaN            NaN            NaN
# Diciembre               NaN              NaN            NaN            NaN
# NaN                     NaN              NaN            NaN            NaN
# Totales       2405702232.92    99857665782.5  4389186936.57  8725482944.22
#
#                     Sellos
# 2022
# NaN                 Sellos
# NaN                    NaN
# Enero            960633347
# NaN                    NaN
# Febrero          851884008
# NaN                    NaN
# Marzo            810314736
# NaN                    NaN
# Abril         952296514.58
# NaN                    NaN
# Mayo            1083550836
# NaN                    NaN
# Junio           1081415464
# NaN                    NaN
# Julio           1138253314
# NaN                    NaN
# Agosto          1189081026
# NaN                    NaN
# Septiembre      1405661757
# NaN                    NaN
# Octubre         1211572656
# NaN                    NaN
# Noviembre       1275325918
# NaN                    NaN
# Diciembre              NaN
# NaN                    NaN
# Totales     11959989576.58

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# >***Ahora al indice del dataframe, en donde estan los meses del ejercicio fiscal, le vamos a poner un nombre, para luego, ingresarlo como columna al dataframe...***
# </font>
# </p>

# %%
df.index.name = "Mes"

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#            Mes  Ingresos Varios  Ingresos Brutos   Inmobiliario  \
# 0          NaN  Ingresos Varios  Ingresos Brutos   Inmobiliario
# 1          NaN              NaN              NaN            NaN
# 2        Enero        179013389       6815275641       83236124
# 3          NaN              NaN              NaN            NaN
# 4      Febrero        223999109       6525087915      327088196
# 5          NaN              NaN              NaN            NaN
# 6        Marzo        218445045       6633613415     1377477738
# 7          NaN              NaN              NaN            NaN
# 8        Abril     233420590.92     7882943560.5   214670297.57
# 9          NaN              NaN              NaN            NaN
# 10        Mayo        260269325       8485148694      429439154
# 11         NaN              NaN              NaN            NaN
# 12       Junio        243073675       8272230858      192503829
# 13         NaN              NaN              NaN            NaN
# 14       Julio        187551741       9777144943      423569483
# 15         NaN              NaN              NaN            NaN
# 16      Agosto        214209657      10673847335      208783168
# 17         NaN              NaN              NaN            NaN
# 18  Septiembre        220741077      10903034059      454538851
# 19         NaN              NaN              NaN            NaN
# 20     Octubre        203839854      11468663772      212987319
# 21         NaN              NaN              NaN            NaN
# 22   Noviembre        221138770      12420675590      464892777
# 23         NaN              NaN              NaN            NaN
# 24   Diciembre              NaN              NaN            NaN
# 25         NaN              NaN              NaN            NaN
# 26     Totales    2405702232.92    99857665782.5  4389186936.57
#
#         Automotor          Sellos
# 0       Automotor          Sellos
# 1             NaN             NaN
# 2       277734375       960633347
# 3             NaN             NaN
# 4      2165283816       851884008
# 5             NaN             NaN
# 6       675398064       810314736
# 7             NaN             NaN
# 8    925755849.22    952296514.58
# 9             NaN             NaN
# 10      511257271      1083550836
# 11            NaN             NaN
# 12      986531047      1081415464
# 13            NaN             NaN
# 14      562866368      1138253314
# 15            NaN             NaN
# 16     1051893523      1189081026
# 17            NaN             NaN
# 18      539079630      1405661757
# 19            NaN             NaN
# 20      497258187      1211572656
# 21            NaN             NaN
# 22      532424814      1275325918
# 23            NaN             NaN
# 24            NaN             NaN
# 25            NaN             NaN
# 26  8725482944.22  11959989576.58

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# >***Ahora vamos a eliminar las filas que tengan todos sus datos faltantes, para ello usamos el método de Pandas ```dropna()``` con los parámetros ```axis=0``` para indicar que queremos eliminar las filas, y el parametro ```how=all```, es decir eliminar las filas en donde todos sus datos son faltantes...***
# </font>
# </p>

# %%
df = df.dropna(axis=0, how="all")

# %%
df
# Out:
#            Mes  Ingresos Varios  Ingresos Brutos   Inmobiliario  \
# 0          NaN  Ingresos Varios  Ingresos Brutos   Inmobiliario
# 2        Enero        179013389       6815275641       83236124
# 4      Febrero        223999109       6525087915      327088196
# 6        Marzo        218445045       6633613415     1377477738
# 8        Abril     233420590.92     7882943560.5   214670297.57
# 10        Mayo        260269325       8485148694      429439154
# 12       Junio        243073675       8272230858      192503829
# 14       Julio        187551741       9777144943      423569483
# 16      Agosto        214209657      10673847335      208783168
# 18  Septiembre        220741077      10903034059      454538851
# 20     Octubre        203839854      11468663772      212987319
# 22   Noviembre        221138770      12420675590      464892777
# 24   Diciembre              NaN              NaN            NaN
# 26     Totales    2405702232.92    99857665782.5  4389186936.57
#
#         Automotor          Sellos
# 0       Automotor          Sellos
# 2       277734375       960633347
# 4      2165283816       851884008
# 6       675398064       810314736
# 8    925755849.22    952296514.58
# 10      511257271      1083550836
# 12      986531047      1081415464
# 14      562866368      1138253314
# 16     1051893523      1189081026
# 18      539079630      1405661757
# 20      497258187      1211572656
# 22      532424814      1275325918
# 24            NaN             NaN
# 26  8725482944.22  11959989576.58

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# >***Lo que vamos a hacer ahora, es ordenar el indice, usando el método ```reset_index()```, eliminando el índice, sin ingresarlo al dataframe, y con posterioridad a ello, vamos a eliminar la primera fila y la última fila del dataframe, pero con el uso de filtros...***
# </font>
# </p>

# %%
df.reset_index(drop=True, inplace=True)

# %%
df = df[(df.Automotor != "Automotor") & (df.Mes != "Totales")]

# %%
df
# Out:
#            Mes Ingresos Varios Ingresos Brutos  Inmobiliario     Automotor  \
# 1        Enero       179013389      6815275641      83236124     277734375
# 2      Febrero       223999109      6525087915     327088196    2165283816
# 3        Marzo       218445045      6633613415    1377477738     675398064
# 4        Abril    233420590.92    7882943560.5  214670297.57  925755849.22
# 5         Mayo       260269325      8485148694     429439154     511257271
# 6        Junio       243073675      8272230858     192503829     986531047
# 7        Julio       187551741      9777144943     423569483     562866368
# 8       Agosto       214209657     10673847335     208783168    1051893523
# 9   Septiembre       220741077     10903034059     454538851     539079630
# 10     Octubre       203839854     11468663772     212987319     497258187
# 11   Noviembre       221138770     12420675590     464892777     532424814
# 12   Diciembre             NaN             NaN           NaN           NaN
#
#           Sellos
# 1      960633347
# 2      851884008
# 3      810314736
# 4   952296514.58
# 5     1083550836
# 6     1081415464
# 7     1138253314
# 8     1189081026
# 9     1405661757
# 10    1211572656
# 11    1275325918
# 12           NaN

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# >***Ahora vamos a verificar el tipo de datos de cada una de las series del dataframe, y convertir los ```objects``` en ```float```, para ello, vamos a sacar la serie Mes, convirtiendola en el indice, y luego le vamos a aplicar el cambio del tipo de dato a todo el dataframe...***
# </font>
# </p>

# %%
df.set_index("Mes", drop=True, inplace=True)

# %%
df
# Out:
#            Ingresos Varios Ingresos Brutos  Inmobiliario     Automotor  \
# Mes
# Enero            179013389      6815275641      83236124     277734375
# Febrero          223999109      6525087915     327088196    2165283816
# Marzo            218445045      6633613415    1377477738     675398064
# Abril         233420590.92    7882943560.5  214670297.57  925755849.22
# Mayo             260269325      8485148694     429439154     511257271
# Junio            243073675      8272230858     192503829     986531047
# Julio            187551741      9777144943     423569483     562866368
# Agosto           214209657     10673847335     208783168    1051893523
# Septiembre       220741077     10903034059     454538851     539079630
# Octubre          203839854     11468663772     212987319     497258187
# Noviembre        221138770     12420675590     464892777     532424814
# Diciembre              NaN             NaN           NaN           NaN
#
#                   Sellos
# Mes
# Enero          960633347
# Febrero        851884008
# Marzo          810314736
# Abril       952296514.58
# Mayo          1083550836
# Junio         1081415464
# Julio         1138253314
# Agosto        1189081026
# Septiembre    1405661757
# Octubre       1211572656
# Noviembre     1275325918
# Diciembre            NaN

# %%
df = df.astype("float")

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#            Mes  Ingresos Varios  Ingresos Brutos  Inmobiliario     Automotor  \
# 0        Enero     1.790134e+08     6.815276e+09  8.323612e+07  2.777344e+08
# 1      Febrero     2.239991e+08     6.525088e+09  3.270882e+08  2.165284e+09
# 2        Marzo     2.184450e+08     6.633613e+09  1.377478e+09  6.753981e+08
# 3        Abril     2.334206e+08     7.882944e+09  2.146703e+08  9.257558e+08
# 4         Mayo     2.602693e+08     8.485149e+09  4.294392e+08  5.112573e+08
# 5        Junio     2.430737e+08     8.272231e+09  1.925038e+08  9.865310e+08
# 6        Julio     1.875517e+08     9.777145e+09  4.235695e+08  5.628664e+08
# 7       Agosto     2.142097e+08     1.067385e+10  2.087832e+08  1.051894e+09
# 8   Septiembre     2.207411e+08     1.090303e+10  4.545389e+08  5.390796e+08
# 9      Octubre     2.038399e+08     1.146866e+10  2.129873e+08  4.972582e+08
# 10   Noviembre     2.211388e+08     1.242068e+10  4.648928e+08  5.324248e+08
# 11   Diciembre              NaN              NaN           NaN           NaN
#
#           Sellos
# 0   9.606333e+08
# 1   8.518840e+08
# 2   8.103147e+08
# 3   9.522965e+08
# 4   1.083551e+09
# 5   1.081415e+09
# 6   1.138253e+09
# 7   1.189081e+09
# 8   1.405662e+09
# 9   1.211573e+09
# 10  1.275326e+09
# 11           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Mes              12 non-null     object
#  1   Ingresos Varios  11 non-null     float64
#  2   Ingresos Brutos  11 non-null     float64
#  3   Inmobiliario     11 non-null     float64
#  4   Automotor        11 non-null     float64
#  5   Sellos           11 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 704.0+ bytes

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# >***Ahora, solo a los efectos estéticos, vamos a configurar que los datos numéricos no tengan notación científica, y que tengan dos decimales, (este tema lo vamos a desarrollar en el próximo notebook)...***
# </font>
# </p>

# %%
pd.options.display.precision = 2
pd.options.display.float_format = "{:.2f}".format

# %%
df
# Out:
#            Mes  Ingresos Varios  Ingresos Brutos  Inmobiliario     Automotor  \
# 0        Enero     179013389.00    6815275641.00   83236124.00  277734375.00
# 1      Febrero     223999109.00    6525087915.00  327088196.00 2165283816.00
# 2        Marzo     218445045.00    6633613415.00 1377477738.00  675398064.00
# 3        Abril     233420590.92    7882943560.50  214670297.57  925755849.22
# 4         Mayo     260269325.00    8485148694.00  429439154.00  511257271.00
# 5        Junio     243073675.00    8272230858.00  192503829.00  986531047.00
# 6        Julio     187551741.00    9777144943.00  423569483.00  562866368.00
# 7       Agosto     214209657.00   10673847335.00  208783168.00 1051893523.00
# 8   Septiembre     220741077.00   10903034059.00  454538851.00  539079630.00
# 9      Octubre     203839854.00   11468663772.00  212987319.00  497258187.00
# 10   Noviembre     221138770.00   12420675590.00  464892777.00  532424814.00
# 11   Diciembre              NaN              NaN           NaN           NaN
#
#           Sellos
# 0   960633347.00
# 1   851884008.00
# 2   810314736.00
# 3   952296514.58
# 4  1083550836.00
# 5  1081415464.00
# 6  1138253314.00
# 7  1189081026.00
# 8  1405661757.00
# 9  1211572656.00
# 10 1275325918.00
# 11           NaN

# %% [markdown]
# <p align="justify">
# <font color="DeepPink">
#
# ✅ **Ya tenemos nuestro dataframe correspondiente al ejercicio fiscal $2022$ con los datos numéricos.**
# </font>
# </p>

# %% [markdown]
# ---
# <p align="justify">
# <font color="DeepPink">
#
# 💗 **El desafío ahora, es automatizar los scrips para que de la lista inicial, se puedan crear todos los dataframes resultantes en virtud de los ejercicios fiscales que tiene la lista, es decir, desde el año $2000$ hasta el año $2022$.**
# </font>
# </p>
#
# ---
